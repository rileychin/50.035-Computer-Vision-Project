# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import PIL
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
from tqdm import tqdm
import tensorflow_addons as tfa
import random
from sklearn.preprocessing import MultiLabelBinarizer
from PIL import Image

pd.set_option("display.max_columns", None)

print('success')
# Out:
# success

# %% [markdown]
# ### Processing images
# #### Example taken from: https://www.kaggle.com/seyunhan/inceptionresnetv2-keras-pbl4
#
# We load the train,test,val images here

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train['labels'] = train['labels'].apply(lambda string: string.split(' '))
train
# Out:
#                       image                               labels
# 0      800113bb65efe69e.jpg                            [healthy]
# 1      8002cb321f8bfcdf.jpg  [scab, frog_eye_leaf_spot, complex]
# 2      80070f7fb5e2ccaa.jpg                               [scab]
# 3      80077517781fb94f.jpg                               [scab]
# 4      800cbf0ff87721f8.jpg                            [complex]
# ...                     ...                                  ...
# 17696  fffb900a92289a33.jpg                            [healthy]
# 17697  fffc488fa4c0e80c.jpg                               [scab]
# 17698  fffc94e092a59086.jpg                               [rust]
# 17699  fffe105cf6808292.jpg           [scab, frog_eye_leaf_spot]
# 17700  fffe472a0001bd25.jpg                            [healthy]
#
# [17701 rows x 2 columns]

# %%
s = list(train['labels'])
mlb = MultiLabelBinarizer()
trainx = pd.DataFrame(mlb.fit_transform(s), columns=mlb.classes_, index=train.index)
print(trainx.columns)
print(trainx.sum())

labels = list(trainx.sum().keys())
print(labels)
label_counts = trainx.sum().values.tolist()

fig, ax = plt.subplots(1,1, figsize=(20,6))

sns.barplot(x= labels, y= label_counts, ax=ax)
# Out:
# Index(['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust',
#        'scab'],
#       dtype='object')
# complex               2037
# frog_eye_leaf_spot    4139
# healthy               4396
# powdery_mildew        1210
# rust                  1963
# scab                  5435
# dtype: int64
# ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']
# <AxesSubplot:>

# %% [markdown]
# ### Viewing some images

# %%
fig1 = plt.figure(figsize=(26,10))

for i in range(1, 13):
    
    rand =  random.randrange(1, len(list(train['image'])))
    sample = os.path.join('./train_images/', train['image'][rand])
    
    img = Image.open(sample)
    
    ax = fig1.add_subplot(4,3,i)
    ax.imshow(img)
    
    title = f"{train['labels'][rand]}{img.size}"
    plt.title(title)
    
    fig1.tight_layout()

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1/255.0,
                            rotation_range=5,
                            zoom_range=0.1,
                            shear_range=0.05,
                            horizontal_flip=True,
                            validation_split=0.1)

train_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='training',
    x_col='image',
    y_col='labels',
    target_size=(224,224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )

#'../input/plant-pathology-2021-fgvc8/train_images'
valid_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='validation',
    x_col='image',
    y_col='labels',
    target_size=(224,224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )
# Out:
# Found 15931 validated image filenames belonging to 6 classes.
# Found 1770 validated image filenames belonging to 6 classes.

# %%
import h5py

# %%
seed = 1200
tf.random.set_seed(seed)

# weights_path = '../input/keras-pretrained-models/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5'
# model = keras.applications.InceptionResNetV2(weights=weights_path, include_top=False, input_shape=(224, 224, 3))
model = keras.applications.NASNetLarge(input_shape=(331, 331, 3), include_top=False, weights='imagenet', classes=1000)
print(model.input)
print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 331, 331, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 11, 11, 4032), dtype=tf.float32, name=None), name='activation_259/Relu:0', description="created by layer 'activation_259'")

# %%
new_model = tf.keras.Sequential([
    model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(6, 
        kernel_initializer=keras.initializers.RandomUniform(seed=seed),
        bias_initializer=keras.initializers.Zeros(), name='dense_top', activation='sigmoid')
])

# Freezing the weights
for layer in new_model.layers[:-1]:
    layer.trainable=False
    
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  NASNet (Functional)         (None, 11, 11, 4032)      84916818
#
#  global_average_pooling2d (G  (None, 4032)             0
#  lobalAveragePooling2D)
#
#  dense_top (Dense)           (None, 6)                 24198
#
# =================================================================
# Total params: 84,941,016
# Trainable params: 24,198
# Non-trainable params: 84,916,818
# _________________________________________________________________

# %%
## TO use CPU
CUDA_VISIBLE_DEVICES=""
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
print('success')
# Out:
# success

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))

# tf.config.experimental.set_memory_growth(
#     physical_devices[0], enable='True'
# )

# import PIL.Image
# Out:
# Num GPUs Available:  0

# %%
from tensorflow.keras.callbacks import EarlyStopping
import PIL
f1 = tfa.metrics.F1Score(num_classes=6,average='macro')

new_model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy',f1])
callbacks = keras.callbacks.EarlyStopping(monitor=f1, patience=4, mode='max', restore_best_weights=True)
history = new_model.fit_generator(generator=train_generator,
                    validation_data=valid_generator,
                    epochs=65,
                    steps_per_epoch=train_generator.samples//256, # = 58
                    validation_steps=valid_generator.samples//128,
                    callbacks=callbacks)
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_24456\3583829206.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = new_model.fit_generator(generator=train_generator,
# Epoch 1/65
# 62/62 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.4108 - f1_score: 0.2996
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\riley\Desktop\SUTD stuff\Term 7 (ISTD Senior)\50.035 Computer Vision\Project\NasNet_Riley.ipynb Cell 14' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=4'>5</a> new_model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy',f1])
#       <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=5'>6</a> callbacks = keras.callbacks.EarlyStopping(monitor=f1, patience=4, mode='max', restore_best_weights=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=6'>7</a> history = new_model.fit_generator(generator=train_generator,
#       <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=7'>8</a>                     validation_data=valid_generator,
#       <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=8'>9</a>                     epochs=65,
#      <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=9'>10</a>                     steps_per_epoch=train_generator.samples//256, # = 58
#      <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=10'>11</a>                     validation_steps=valid_generator.samples//128,
#      <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/NasNet_Riley.ipynb#ch0000013?line=11'>12</a>                     callbacks=callbacks)
#
# File ~\anaconda3\envs\cv\lib\site-packages\keras\engine\training.py:2209, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2197'>2198</a> """Fits the model on data yielded batch-by-batch by a Python generator.
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2198'>2199</a>
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2199'>2200</a> DEPRECATED:
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2200'>2201</a>   `Model.fit` now supports generators, so there is no longer any need to use
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2201'>2202</a>   this endpoint.
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2202'>2203</a> """
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2203'>2204</a> warnings.warn(
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2204'>2205</a>     '`Model.fit_generator` is deprecated and '
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2205'>2206</a>     'will be removed in a future version. '
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2206'>2207</a>     'Please use `Model.fit`, which supports generators.',
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2207'>2208</a>     stacklevel=2)
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2208'>2209</a> return self.fit(
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2209'>2210</a>     generator,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2210'>2211</a>     steps_per_epoch=steps_per_epoch,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2211'>2212</a>     epochs=epochs,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2212'>2213</a>     verbose=verbose,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2213'>2214</a>     callbacks=callbacks,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2214'>2215</a>     validation_data=validation_data,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2215'>2216</a>     validation_steps=validation_steps,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2216'>2217</a>     validation_freq=validation_freq,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2217'>2218</a>     class_weight=class_weight,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2218'>2219</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2219'>2220</a>     workers=workers,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2220'>2221</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2221'>2222</a>     shuffle=shuffle,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=2222'>2223</a>     initial_epoch=initial_epoch)
#
# File ~\anaconda3\envs\cv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\cv\lib\site-packages\keras\engine\training.py:1420, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1405'>1406</a> if getattr(self, '_eval_data_handler', None) is None:
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1406'>1407</a>   self._eval_data_handler = data_adapter.get_data_handler(
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1407'>1408</a>       x=val_x,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1408'>1409</a>       y=val_y,
#    (...)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1417'>1418</a>       model=self,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1418'>1419</a>       steps_per_execution=self._steps_per_execution)
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1419'>1420</a> val_logs = self.evaluate(
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1420'>1421</a>     x=val_x,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1421'>1422</a>     y=val_y,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1422'>1423</a>     sample_weight=val_sample_weight,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1423'>1424</a>     batch_size=validation_batch_size or batch_size,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1424'>1425</a>     steps=validation_steps,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1425'>1426</a>     callbacks=callbacks,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1426'>1427</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1427'>1428</a>     workers=workers,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1428'>1429</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1429'>1430</a>     return_dict=True,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1430'>1431</a>     _use_cached_eval_dataset=True)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1431'>1432</a> val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1432'>1433</a> epoch_logs.update(val_logs)
#
# File ~\anaconda3\envs\cv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\cv\lib\site-packages\keras\engine\training.py:1716, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1713'>1714</a> with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1714'>1715</a>   callbacks.on_test_batch_begin(step)
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1715'>1716</a>   tmp_logs = self.test_function(iterator)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1716'>1717</a>   if data_handler.should_sync:
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/keras/engine/training.py?line=1717'>1718</a>     context.async_wait()
#
# File ~\anaconda3\envs\cv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\cv\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=911'>912</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=913'>914</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=914'>915</a>   result = self._call(*args, **kwds)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=916'>917</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=917'>918</a> without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\cv\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=950'>951</a> self._lock.release()
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=951'>952</a> # In this case we have not created variables on the first call. So we can
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=952'>953</a> # run the first trace but we should fail if variables are created.
# --> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=953'>954</a> results = self._stateful_fn(*args, **kwds)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=954'>955</a> if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=955'>956</a>   raise ValueError("Creating variables on a non-first call to a function"
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/def_function.py?line=956'>957</a>                    " decorated with tf.function.")
#
# File ~\anaconda3\envs\cv\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=2952'>2953</a> with self._lock:
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=2953'>2954</a>   (graph_function,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=2954'>2955</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=2955'>2956</a> return graph_function._call_flat(
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=2956'>2957</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\envs\cv\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1848'>1849</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1849'>1850</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1850'>1851</a>     and executing_eagerly):
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1851'>1852</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1852'>1853</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1853'>1854</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1854'>1855</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1855'>1856</a>     args,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1856'>1857</a>     possible_gradient_type,
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1857'>1858</a>     executing_eagerly)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=1858'>1859</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\envs\cv\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=496'>497</a> with _InterpolateFunctionError(self):
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=497'>498</a>   if cancellation_manager is None:
# --> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=498'>499</a>     outputs = execute.execute(
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=499'>500</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=500'>501</a>         num_outputs=self._num_outputs,
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=501'>502</a>         inputs=args,
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=502'>503</a>         attrs=attrs,
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=503'>504</a>         ctx=ctx)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=504'>505</a>   else:
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=505'>506</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=506'>507</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=507'>508</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=510'>511</a>         ctx=ctx,
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/function.py?line=511'>512</a>         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\envs\cv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Making predictions

# %%
for img_name in tqdm(test['image']):
    path = './test_images/'+str(img_name)
    with PIL.Image.open(path) as img:
        img = img.resize((256,256))
        img.save(f'./test_size256_images/{img_name}')
# Out:
# 100%|██████████| 931/931 [01:27<00:00, 10.67it/s]

# %%
import time
test_data = datagen.flow_from_dataframe(
    test,
    directory = './test_size256_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (256,256),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

## Getting time of execution 
start_time = time.time()
preds = new_model.predict(test_data)
print("--- %s seconds ---" % (time.time() - start_time))

print(preds)
preds = preds.tolist()

indices = []
for pred in preds:
    temp = []
    for category in pred:
        if category>=0.3:
            temp.append(pred.index(category))
    if temp!=[]:
        indices.append(temp)
    else:
        temp.append(np.argmax(pred))
        indices.append(temp)
    
print(indices)
# Out:
# Found 931 validated image filenames.
# [[3.25453222e-01 3.11547577e-01 9.04463232e-02 1.27381980e-02
#   1.70397162e-01 2.78822780e-02]
#  [9.52970386e-02 3.13880950e-01 2.03315496e-01 2.66820192e-04
#   9.94974375e-03 2.26879895e-01]
#  [5.15023470e-02 2.68827975e-02 1.55876875e-02 2.31239498e-02
#   6.28325343e-03 7.61370361e-01]
#  ...
og_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot scab', 'healthy', 'complex powdery_mildew', 'frog_eye_leaf_spot scab', 'complex frog_eye_leaf_spot scab', 'scab', 'scab', 'rust', 'healthy scab', 'complex frog_eye_leaf_spot', 'healthy', 'scab', 'healthy scab', 'rust', 'scab', 'complex scab', 'complex frog_eye_leaf_spot rust', 'scab', 'scab', 'frog_eye_leaf_spot scab', 'complex powdery_mildew', 'powdery_mildew', 'scab', 'complex', 'healthy', 'rust', 'powdery_mildew', 'healthy', 'powdery_mildew', 'powdery_mildew', 'scab', 'healthy', 'powdery_mildew', 'scab', 'healthy scab', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'scab', 'healthy', 'complex frog_eye_leaf_spot', 'scab', 'healthy', 'scab', 'healthy', 'scab', 'healthy', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'healthy scab', 'complex rust', 'scab', 'complex scab', 'powdery_mildew', 'healthy', 'rust', 'healthy', 'healthy', 'rust', 'scab', 'scab', 'healthy scab', 'complex frog_eye_leaf_spot', 'healthy', 'scab', 'healthy scab', 'rust', 'rust', 'complex scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'complex rust scab', 'healthy', 'rust', 'frog_eye_leaf_spot', 'complex frog_eye_leaf_spot scab', 'scab', 'healthy', 'scab', 'rust', 'complex frog_eye_leaf_spot rust', 'rust', 'complex rust', 'scab', 'scab', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot healthy', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'powdery_mildew', 'scab', 'scab', 'rust', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'complex frog_eye_leaf_spot', 'complex scab', 'frog_eye_leaf_spot healthy', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'scab', 'healthy', 'frog_eye_leaf_spot scab', 'scab', 'complex frog_eye_leaf_spot scab', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot rust scab', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot scab', 'complex frog_eye_leaf_spot', 'complex frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy scab', 'healthy', 'scab', 'scab', 'complex powdery_mildew', 'scab', 'healthy', 'healthy scab', 'healthy', 'healthy', 'complex scab', 'healthy', 'frog_eye_leaf_spot healthy', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew scab', 'complex frog_eye_leaf_spot', 'complex frog_eye_leaf_spot', 'complex scab', 'complex', 'complex', 'healthy', 'complex frog_eye_leaf_spot rust', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'complex frog_eye_leaf_spot scab', 'scab', 'rust', 'scab', 'complex', 'frog_eye_leaf_spot', 'scab', 'healthy scab', 'scab', 'complex frog_eye_leaf_spot rust', 'complex frog_eye_leaf_spot scab', 'scab', 'rust', 'healthy scab', 'healthy', 'scab', 'scab', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'complex rust', 'complex frog_eye_leaf_spot', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'complex frog_eye_leaf_spot rust', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'complex frog_eye_leaf_spot', 'healt ...

# %%
actuallabels = list(test['labels'])
print(actuallabels)
# Out:
# ['frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'complex', 'powdery_mildew', 'healthy', 'scab', 'complex', 'healthy', 'healthy', 'rust', 'scab', 'complex', 'scab', 'healthy', 'scab', 'powdery_mildew', 'healthy', 'rust', 'frog_eye_leaf_spot', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'healthy', 'complex', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'healthy', 'scab', 'rust', 'healthy', 'rust', 'powdery_mildew', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'rust', 'rust', 'complex', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'scab', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab', 'complex', 'rust', 'healthy', 'complex', 'healthy', 'complex', 'scab', 'rust', 'scab', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'rust', 'powdery_mildew', 'healthy', 'powdery_mildew', 'powdery_mildew', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'healthy', 'rust', 'scab', 'healthy', 'complex', 'scab', 'powdery_mildew', 'scab', 'healthy', 'scab', 'healthy', 'scab', 'complex', 'scab', 'complex', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'powdery_mildew complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'scab', 'rust', 'scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'complex', 'rust', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'rust', 'rust', 'rust', 'rust', 'healthy', 'rust', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'powdery_mildew', 'scab', 'scab', 'rust', 'healthy', 'scab frog_eye_leaf_spot complex', 'scab frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'healthy', 'healthy', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'rust', 'powdery_mildew', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot complex', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'scab', 'powdery_mildew complex', 'rust frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'rust', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'complex', 'scab', 'healthy', 'frog_eye_leaf_spot', 'rust', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'rust', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'rust', 'complex', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'rust complex', 'healthy', 'scab', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot comple ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(actuallabels,testlabels)
print(f"Test accuracy score: {accuracy}")
# Out:
# Test accuracy score: 0.5123523093447906

# %%
actual_test = pd.read_csv('sample_submission.csv')

# %%
actual_test_data = datagen.flow_from_dataframe(
    actual_test,
    directory = './actual_test_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (256,256),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

actual_preds = new_model.predict(actual_test_data)
print(actual_preds)
actual_preds = actual_preds.tolist()

indices = []
for pred in actual_preds:
    temp = []
    for category in pred:
        if category>=0.3:
            temp.append(pred.index(category))
    if temp!=[]:
        indices.append(temp)
    else:
        temp.append(np.argmax(pred))
        indices.append(temp)
    
print(indices)
# Out:
# Found 3 validated image filenames.
# [[7.2029662e-01 2.9084563e-01 9.1618299e-04 6.3170791e-03 1.7512232e-02
#   1.5388379e-01]
#  [5.2997243e-01 5.2037054e-01 2.9015541e-04 4.2134523e-04 2.7173713e-01
#   1.1389509e-01]
#  [4.0577197e-01 8.7384510e-01 1.2305081e-03 6.9387078e-02 1.3334781e-02
#   4.4005722e-02]]
# [[0], [0, 1], [0, 1]]

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)

actualtestlabels = []


for image in indices:
    temp = []
    for i in image:
        temp.append(str(labels[i]))
    actualtestlabels.append(' '.join(temp))

print(actualtestlabels)
# Out:
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
# ['complex', 'complex frog_eye_leaf_spot', 'complex frog_eye_leaf_spot']

# %%
sub = pd.read_csv('./sample_submission.csv')
sub['labels'] = actualtestlabels
sub.to_csv('submission.csv', index=False)
sub
# Out:
#                   image                      labels
# 0  85f8cb619c66b863.jpg                     complex
# 1  ad8770db05586b59.jpg  complex frog_eye_leaf_spot
# 2  c7b03e718489f3ca.jpg  complex frog_eye_leaf_spot
