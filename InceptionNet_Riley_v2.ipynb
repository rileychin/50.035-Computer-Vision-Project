# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import PIL
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
from tqdm import tqdm
import tensorflow_addons as tfa
import random
from sklearn.preprocessing import MultiLabelBinarizer
from PIL import Image

pd.set_option("display.max_columns", None)

print('success')
# Out:
# success

# %% [markdown]
# ### Processing images
# #### Example taken from: https://www.kaggle.com/seyunhan/inceptionresnetv2-keras-pbl4
#
# We load the train,test,val images here

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train['labels'] = train['labels'].apply(lambda string: string.split(' '))
train
# Out:
#                       image                               labels
# 0      800113bb65efe69e.jpg                            [healthy]
# 1      8002cb321f8bfcdf.jpg  [scab, frog_eye_leaf_spot, complex]
# 2      80070f7fb5e2ccaa.jpg                               [scab]
# 3      80077517781fb94f.jpg                               [scab]
# 4      800cbf0ff87721f8.jpg                            [complex]
# ...                     ...                                  ...
# 17696  fffb900a92289a33.jpg                            [healthy]
# 17697  fffc488fa4c0e80c.jpg                               [scab]
# 17698  fffc94e092a59086.jpg                               [rust]
# 17699  fffe105cf6808292.jpg           [scab, frog_eye_leaf_spot]
# 17700  fffe472a0001bd25.jpg                            [healthy]
#
# [17701 rows x 2 columns]

# %%
s = list(train['labels'])
mlb = MultiLabelBinarizer()
trainx = pd.DataFrame(mlb.fit_transform(s), columns=mlb.classes_, index=train.index)
print(trainx.columns)
print(trainx.sum())

labels = list(trainx.sum().keys())
print(labels)
label_counts = trainx.sum().values.tolist()

fig, ax = plt.subplots(1,1, figsize=(20,6))

sns.barplot(x= labels, y= label_counts, ax=ax)
# Out:
# Index(['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust',
#        'scab'],
#       dtype='object')
# complex               2037
# frog_eye_leaf_spot    4139
# healthy               4396
# powdery_mildew        1210
# rust                  1963
# scab                  5435
# dtype: int64
# ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']
# <AxesSubplot:>

# %% [markdown]
# ### Viewing some images

# %%
fig1 = plt.figure(figsize=(26,10))

for i in range(1, 13):
    
    rand =  random.randrange(1, len(list(train['image'])))
    sample = os.path.join('./train_images/', train['image'][rand])
    
    img = Image.open(sample)
    
    ax = fig1.add_subplot(4,3,i)
    ax.imshow(img)
    
    title = f"{train['labels'][rand]}{img.size}"
    plt.title(title)
    
    fig1.tight_layout()

# %%
from keras.preprocessing.image import ImageDataGenerator

TARGET_SIZE = 480

datagen = ImageDataGenerator(rescale=1/255.0,
                            rotation_range=5,
                            zoom_range=0.1,
                            shear_range=0.05,
                            horizontal_flip=True,
                            validation_split=0.1)

train_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='training',
    x_col='image',
    y_col='labels',
    target_size=(TARGET_SIZE,TARGET_SIZE),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )

#'../input/plant-pathology-2021-fgvc8/train_images'
valid_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='validation',
    x_col='image',
    y_col='labels',
    target_size=(TARGET_SIZE,TARGET_SIZE),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )
# Out:
# Found 15931 validated image filenames belonging to 6 classes.
# Found 1770 validated image filenames belonging to 6 classes.

# %%
import h5py

# %%
seed = 1200
tf.random.set_seed(seed)

# weights_path = '../input/keras-pretrained-models/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5'
model = keras.applications.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(224,224, 3))
# model = keras.applications.NASNetLarge(input_shape=(331, 331, 3), include_top=False, weights='imagenet', classes=1000)
print(model.input)
print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 480, 480, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 13, 13, 1536), dtype=tf.float32, name=None), name='conv_7b_ac/Relu:0', description="created by layer 'conv_7b_ac'")

# %%
new_model = tf.keras.Sequential([
    model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(6, 
        kernel_initializer=keras.initializers.RandomUniform(seed=seed),
        bias_initializer=keras.initializers.Zeros(), name='dense_top', activation='sigmoid')
])

# Freezing the weights
for layer in new_model.layers[:-1]:
    layer.trainable=False
    
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 13, 13, 1536)     54336736
#  onal)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense_top (Dense)           (None, 6)                 9222
#
# =================================================================
# Total params: 54,345,958
# Trainable params: 9,222
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
## TO use CPU
CUDA_VISIBLE_DEVICES=""
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
print('success')
# Out:
# success

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))

# tf.config.experimental.set_memory_growth(
#     physical_devices[0], enable='True'
# )

# import PIL.Image
# Out:
# Num GPUs Available:  0

# %%
from tensorflow.keras.callbacks import EarlyStopping
import PIL
f1 = tfa.metrics.F1Score(num_classes=6,average='macro')

new_model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy',f1])
callbacks = keras.callbacks.EarlyStopping(monitor=f1, patience=4, mode='max', restore_best_weights=True)
history = new_model.fit_generator(generator=train_generator,
                    validation_data=valid_generator,
                    epochs=65,
                    steps_per_epoch=train_generator.samples//256, # = 58
                    validation_steps=valid_generator.samples//128,
                    callbacks=callbacks)
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_4628\3583829206.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = new_model.fit_generator(generator=train_generator,
# Epoch 1/65
# 62/62 [==============================] - ETA: 0s - loss: 0.4597 - accuracy: 0.2999 - f1_score: 0.1866WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 611s 10s/step - loss: 0.4597 - accuracy: 0.2999 - f1_score: 0.1866 - val_loss: 0.4145 - val_accuracy: 0.4135 - val_f1_score: 0.2089
# Epoch 2/65
# 62/62 [==============================] - ETA: 0s - loss: 0.4041 - accuracy: 0.4360 - f1_score: 0.2962WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 625s 10s/step - loss: 0.4041 - accuracy: 0.4360 - f1_score: 0.2962 - val_loss: 0.3921 - val_accuracy: 0.4519 - val_f1_score: 0.3466
# Epoch 3/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3820 - accuracy: 0.4945 - f1_score: 0.3926WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 613s 10s/step - loss: 0.3820 - accuracy: 0.4945 - f1_score: 0.3926 - val_loss: 0.3554 - val_accuracy: 0.5048 - val_f1_score: 0.3824
# Epoch 4/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.5343 - f1_score: 0.4466WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 630s 10s/step - loss: 0.3600 - accuracy: 0.5343 - f1_score: 0.4466 - val_loss: 0.3493 - val_accuracy: 0.5409 - val_f1_score: 0.4336
# Epoch 5/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.5197 - f1_score: 0.4311WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 628s 10s/step - loss: 0.3570 - accuracy: 0.5197 - f1_score: 0.4311 - val_loss: 0.3615 - val_accuracy: 0.4760 - val_f1_score: 0.3941
# Epoch 6/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3535 - accuracy: 0.5297 - f1_score: 0.4624WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 631s 10s/step - loss: 0.3535 - accuracy: 0.5297 - f1_score: 0.4624 - val_loss: 0.3419 - val_accuracy: 0.5457 - val_f1_score: 0.4502
# Epoch 7/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3458 - accuracy: 0.5706 - f1_score: 0.4952WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 628s 10s/step - loss: 0.3458 - accuracy: 0.5706 - f1_score: 0.4952 - val_loss: 0.3198 - val_accuracy: 0.5793 - val_f1_score: 0.4995
# Epoch 8/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.5655 - f1_score: 0.4968WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 632s 10s/step - loss: 0.3347 - accuracy: 0.5655 - f1_score: 0.4968 - val_loss: 0.3240 - val_accuracy: 0.5793 - val_f1_score: 0.5170
# Epoch 9/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.5615 - f1_score: 0.5064WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 629s 10s/step - loss: 0.3373 - accuracy: 0.5615 - f1_score: 0.5064 - val_loss: 0.3245 - val_accuracy: 0.5721 - val_f1_score: 0.4637
# Epoch 10/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.5629 - f1_score: 0.4916WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 619s 10s/step - loss: 0.3303 - accuracy: 0.5629 - f1_score: 0.4916 - val_loss: 0.3240 - val_accuracy: 0.5697 - val_f1_score: 0.4941
# Epoch 11/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3167 - accuracy: 0.6048 - f1_score: 0.5356WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 609s 10s/step - loss: 0.3167 - accuracy: 0.6048 - f1_score: 0.5356 - val_loss: 0.3138 - val_accuracy: 0.5553 - val_f1_score: 0.4577
# Epoch 12/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3172 - accuracy: 0.6048 - f1_score: 0.5341WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 613s 10s/step - loss: 0.3172 - accuracy: 0.6048 - f1_score: 0.5341 - val_loss: 0.3181 - val_accuracy: 0.5793 - val_f1_score: 0.5502
# Epoch 13/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.6058 - f1_score: 0.5339WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 607s 10s/step - loss: 0.3129 - accuracy: 0.6058 - f1_score: 0.5339 - val_loss: 0.3177 - val_accuracy: 0.6034 - val_f1_score: 0.5451
# Epoch 14/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.6008 - f1_score: 0.5398WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 611s 10s/step - loss: 0.3161 - accuracy: 0.6008 - f1_score: 0.5398 - val_loss: 0.3031 - val_accuracy: 0.5938 - val_f1_score: 0.5460
# Epoch 15/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.6013 - f1_score: 0.5500WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 610s 10s/step - loss: 0.3070 - accuracy: 0.6013 - f1_score: 0.5500 - val_loss: 0.2982 - val_accuracy: 0.6058 - val_f1_score: 0.5158
# Epoch 16/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.6250 - f1_score: 0.5716WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 609s 10s/step - loss: 0.3038 - accuracy: 0.6250 - f1_score: 0.5716 - val_loss: 0.3068 - val_accuracy: 0.6034 - val_f1_score: 0.5248
# Epoch 17/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3102 - accuracy: 0.6079 - f1_score: 0.5568WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 611s 10s/step - loss: 0.3102 - accuracy: 0.6079 - f1_score: 0.5568 - val_loss: 0.3126 - val_accuracy: 0.5889 - val_f1_score: 0.4967
# Epoch 18/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3062 - accuracy: 0.6235 - f1_score: 0.5570WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 613s 10s/step - loss: 0.3062 - accuracy: 0.6235 - f1_score: 0.5570 - val_loss: 0.2987 - val_accuracy: 0.6587 - val_f1_score: 0.6042
# Epoch 19/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.6174 - f1_score: 0.5643WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 607s 10s/step - loss: 0.3043 - accuracy: 0.6174 - f1_score: 0.5643 - val_loss: 0.2826 - val_accuracy: 0.6514 - val_f1_score: 0.5885
# Epoch 20/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.6114 - f1_score: 0.5617WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 612s 10s/step - loss: 0.3061 - accuracy: 0.6114 - f1_score: 0.5617 - val_loss: 0.2932 - val_accuracy: 0.6274 - val_f1_score: 0.5833
# Epoch 21/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.6190 - f1_score: 0.5769WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 613s 10s/step - loss: 0.2955 - accuracy: 0.6190 - f1_score: 0.5769 - val_loss: 0.2797 - val_accuracy: 0.6611 - val_f1_score: 0.5945
# Epoch 22/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.6265 - f1_score: 0.5722WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 609s 10s/step - loss: 0.3022 - accuracy: 0.6265 - f1_score: 0.5722 - val_loss: 0.2992 - val_accuracy: 0.6442 - val_f1_score: 0.6196
# Epoch 23/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.6245 - f1_score: 0.5817WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 617s 10s/step - loss: 0.3007 - accuracy: 0.6245 - f1_score: 0.5817 - val_loss: 0.2917 - val_accuracy: 0.6659 - val_f1_score: 0.6165
# Epoch 24/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2999 - accuracy: 0.6225 - f1_score: 0.5822WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 658s 11s/step - loss: 0.2999 - accuracy: 0.6225 - f1_score: 0.5822 - val_loss: 0.2836 - val_accuracy: 0.6250 - val_f1_score: 0.5813
# Epoch 25/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 0.6401 - f1_score: 0.5936WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 641s 10s/step - loss: 0.2971 - accuracy: 0.6401 - f1_score: 0.5936 - val_loss: 0.2812 - val_accuracy: 0.6683 - val_f1_score: 0.6086
# Epoch 26/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.6250 - f1_score: 0.5835WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 646s 10s/step - loss: 0.2988 - accuracy: 0.6250 - f1_score: 0.5835 - val_loss: 0.2719 - val_accuracy: 0.6587 - val_f1_score: 0.5864
# Epoch 27/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.6306 - f1_score: 0.6085WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 665s 11s/step - loss: 0.2921 - accuracy: 0.6306 - f1_score: 0.6085 - val_loss: 0.2767 - val_accuracy: 0.6851 - val_f1_score: 0.6645
# Epoch 28/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.6472 - f1_score: 0.6099WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 691s 11s/step - loss: 0.2874 - accuracy: 0.6472 - f1_score: 0.6099 - val_loss: 0.2873 - val_accuracy: 0.6755 - val_f1_score: 0.6015
# Epoch 29/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.6301 - f1_score: 0.5950WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 674s 11s/step - loss: 0.2990 - accuracy: 0.6301 - f1_score: 0.5950 - val_loss: 0.2716 - val_accuracy: 0.6875 - val_f1_score: 0.6619
# Epoch 30/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.6497 - f1_score: 0.6072WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 690s 11s/step - loss: 0.2860 - accuracy: 0.6497 - f1_score: 0.6072 - val_loss: 0.2684 - val_accuracy: 0.6442 - val_f1_score: 0.5730
# Epoch 31/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.6431 - f1_score: 0.5925WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 704s 11s/step - loss: 0.2904 - accuracy: 0.6431 - f1_score: 0.5925 - val_loss: 0.2574 - val_accuracy: 0.6947 - val_f1_score: 0.6656
# Epoch 32/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2891 - accuracy: 0.6366 - f1_score: 0.5972WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 718s 12s/step - loss: 0.2891 - accuracy: 0.6366 - f1_score: 0.5972 - val_loss: 0.2825 - val_accuracy: 0.6851 - val_f1_score: 0.6521
# Epoch 33/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.6583 - f1_score: 0.6189WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 684s 11s/step - loss: 0.2850 - accuracy: 0.6583 - f1_score: 0.6189 - val_loss: 0.2597 - val_accuracy: 0.6827 - val_f1_score: 0.6452
# Epoch 34/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.6663 - f1_score: 0.6327WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 752s 12s/step - loss: 0.2823 - accuracy: 0.6663 - f1_score: 0.6327 - val_loss: 0.2620 - val_accuracy: 0.6971 - val_f1_score: 0.6623
# Epoch 35/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.6562 - f1_score: 0.6145 WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 767s 12s/step - loss: 0.2867 - accuracy: 0.6562 - f1_score: 0.6145 - val_loss: 0.2704 - val_accuracy: 0.6779 - val_f1_score: 0.6367
# Epoch 36/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2892 - accuracy: 0.6513 - f1_score: 0.6136 WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 820s 13s/step - loss: 0.2892 - accuracy: 0.6513 - f1_score: 0.6136 - val_loss: 0.2677 - val_accuracy: 0.6947 - val_f1_score: 0.6513
# Epoch 37/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.6593 - f1_score: 0.6309 WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 761s 12s/step - loss: 0.2846 - accuracy: 0.6593 - f1_score: 0.6309 - val_loss: 0.2589 - val_accuracy: 0.6851 - val_f1_score: 0.6128
# Epoch 38/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.6665 - f1_score: 0.6130WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 773s 12s/step - loss: 0.2808 - accuracy: 0.6665 - f1_score: 0.6130 - val_loss: 0.2781 - val_accuracy: 0.6538 - val_f1_score: 0.6049
# Epoch 39/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.6694 - f1_score: 0.6462 WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 828s 13s/step - loss: 0.2812 - accuracy: 0.6694 - f1_score: 0.6462 - val_loss: 0.2605 - val_accuracy: 0.6827 - val_f1_score: 0.6364
# Epoch 40/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.6578 - f1_score: 0.6258 WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 831s 13s/step - loss: 0.2787 - accuracy: 0.6578 - f1_score: 0.6258 - val_loss: 0.2639 - val_accuracy: 0.6851 - val_f1_score: 0.6520
# Epoch 41/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.6724 - f1_score: 0.6439WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 713s 11s/step - loss: 0.2735 - accuracy: 0.6724 - f1_score: 0.6439 - val_loss: 0.2661 - val_accuracy: 0.7139 - val_f1_score: 0.6535
# Epoch 42/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.6734 - f1_score: 0.6319WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 657s 11s/step - loss: 0.2752 - accuracy: 0.6734 - f1_score: 0.6319 - val_loss: 0.2621 - val_accuracy: 0.6803 - val_f1_score: 0.6389
# Epoch 43/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.6467 - f1_score: 0.6104WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 714s 12s/step - loss: 0.2874 - accuracy: 0.6467 - f1_score: 0.6104 - val_loss: 0.2641 - val_accuracy: 0.7188 - val_f1_score: 0.6946
# Epoch 44/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.6603 - f1_score: 0.6274WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 696s 11s/step - loss: 0.2865 - accuracy: 0.6603 - f1_score: 0.6274 - val_loss: 0.2743 - val_accuracy: 0.6995 - val_f1_score: 0.6756
# Epoch 45/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.6633 - f1_score: 0.6343WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 725s 12s/step - loss: 0.2831 - accuracy: 0.6633 - f1_score: 0.6343 - val_loss: 0.2626 - val_accuracy: 0.6875 - val_f1_score: 0.6348
# Epoch 46/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.6653 - f1_score: 0.6383 WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 745s 12s/step - loss: 0.2733 - accuracy: 0.6653 - f1_score: 0.6383 - val_loss: 0.2619 - val_accuracy: 0.6587 - val_f1_score: 0.6263
# Epoch 47/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.6593 - f1_score: 0.6254WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 658s 11s/step - loss: 0.2776 - accuracy: 0.6593 - f1_score: 0.6254 - val_loss: 0.2588 - val_accuracy: 0.7260 - val_f1_score: 0.6545
# Epoch 48/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.6603 - f1_score: 0.6343WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 653s 11s/step - loss: 0.2789 - accuracy: 0.6603 - f1_score: 0.6343 - val_loss: 0.2563 - val_accuracy: 0.7188 - val_f1_score: 0.6778
# Epoch 49/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.6547 - f1_score: 0.6320WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 653s 11s/step - loss: 0.2847 - accuracy: 0.6547 - f1_score: 0.6320 - val_loss: 0.2699 - val_accuracy: 0.6731 - val_f1_score: 0.6742
# Epoch 50/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.6724 - f1_score: 0.6547WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 649s 10s/step - loss: 0.2714 - accuracy: 0.6724 - f1_score: 0.6547 - val_loss: 0.2489 - val_accuracy: 0.7236 - val_f1_score: 0.6877
# Epoch 51/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.6598 - f1_score: 0.6329WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 649s 10s/step - loss: 0.2772 - accuracy: 0.6598 - f1_score: 0.6329 - val_loss: 0.2569 - val_accuracy: 0.6779 - val_f1_score: 0.6272
# Epoch 52/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.6724 - f1_score: 0.6401WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 646s 10s/step - loss: 0.2744 - accuracy: 0.6724 - f1_score: 0.6401 - val_loss: 0.2554 - val_accuracy: 0.7067 - val_f1_score: 0.6941
# Epoch 53/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.6734 - f1_score: 0.6400WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 647s 10s/step - loss: 0.2737 - accuracy: 0.6734 - f1_score: 0.6400 - val_loss: 0.2544 - val_accuracy: 0.6995 - val_f1_score: 0.6922
# Epoch 54/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.6633 - f1_score: 0.6370WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 658s 11s/step - loss: 0.2782 - accuracy: 0.6633 - f1_score: 0.6370 - val_loss: 0.2466 - val_accuracy: 0.7500 - val_f1_score: 0.7094
# Epoch 55/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2698 - accuracy: 0.6739 - f1_score: 0.6383WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 659s 11s/step - loss: 0.2698 - accuracy: 0.6739 - f1_score: 0.6383 - val_loss: 0.2450 - val_accuracy: 0.7380 - val_f1_score: 0.6996
# Epoch 56/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.6809 - f1_score: 0.6475WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 658s 11s/step - loss: 0.2689 - accuracy: 0.6809 - f1_score: 0.6475 - val_loss: 0.2532 - val_accuracy: 0.7163 - val_f1_score: 0.6708
# Epoch 57/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.6678 - f1_score: 0.6175WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 657s 11s/step - loss: 0.2778 - accuracy: 0.6678 - f1_score: 0.6175 - val_loss: 0.2497 - val_accuracy: 0.7091 - val_f1_score: 0.6833
# Epoch 58/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.6709 - f1_score: 0.6496WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 657s 11s/step - loss: 0.2713 - accuracy: 0.6709 - f1_score: 0.6496 - val_loss: 0.2703 - val_accuracy: 0.6587 - val_f1_score: 0.6442
# Epoch 59/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.6880 - f1_score: 0.6601WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 659s 11s/step - loss: 0.2715 - accuracy: 0.6880 - f1_score: 0.6601 - val_loss: 0.2523 - val_accuracy: 0.7212 - val_f1_score: 0.6814
# Epoch 60/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.6875 - f1_score: 0.6558WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 667s 11s/step - loss: 0.2679 - accuracy: 0.6875 - f1_score: 0.6558 - val_loss: 0.2471 - val_accuracy: 0.7404 - val_f1_score: 0.7243
# Epoch 61/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.6791 - f1_score: 0.6499WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 657s 11s/step - loss: 0.2693 - accuracy: 0.6791 - f1_score: 0.6499 - val_loss: 0.2559 - val_accuracy: 0.6971 - val_f1_score: 0.6695
# Epoch 62/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.6865 - f1_score: 0.6534WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 658s 11s/step - loss: 0.2724 - accuracy: 0.6865 - f1_score: 0.6534 - val_loss: 0.2517 - val_accuracy: 0.6899 - val_f1_score: 0.6468
# Epoch 63/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.6892 - f1_score: 0.6648WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 655s 11s/step - loss: 0.2655 - accuracy: 0.6892 - f1_score: 0.6648 - val_loss: 0.2459 - val_accuracy: 0.7332 - val_f1_score: 0.6851
# Epoch 64/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.6804 - f1_score: 0.6359WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 659s 11s/step - loss: 0.2696 - accuracy: 0.6804 - f1_score: 0.6359 - val_loss: 0.2484 - val_accuracy: 0.7524 - val_f1_score: 0.7228
# Epoch 65/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.6776 - f1_score: 0.6427WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 658s 11s/step - loss: 0.2704 - accuracy: 0.6776 - f1_score: 0.6427 - val_loss: 0.2640 - val_accuracy: 0.6971 - val_f1_score: 0.6729

# %% [markdown]
# ## Making predictions

# %%
for img_name in tqdm(test['image']):
    path = './test_images/'+str(img_name)
    with PIL.Image.open(path) as img:
        img = img.resize((256,256))
        img.save(f'./test_size256_images/{img_name}')
# Out:
# 100%|██████████| 931/931 [01:31<00:00, 10.13it/s]

# %%
test_data = datagen.flow_from_dataframe(
    test,
    directory = './test_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (TARGET_SIZE,TARGET_SIZE),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

preds = new_model.predict(test_data)
preds = preds.tolist()

# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
threshold = {0: 0.26, # Complex
             5: 0.61, # scab
             1: 0.7, # frog eye leaf spot
             4: 0.5, # rust
             3: 0.5, # powdery mildew
             2: 0.3} #healthy

             
# Can set different threshold here
indices = []
for pred in preds:
    temp = []
    for category in pred:
        if category>=threshold[pred.index(category)]: #assigning a different threshold to each disease
            temp.append(pred.index(category))
    if temp!=[]:
        pass
    else:
        temp.append(np.argmax(pred))
    # only add the predicted healthy labels, remove others
    if 2 in temp:
        temp = [2] # Resets the list 
    indices.append(temp)
    
    
print(indices)
# Out:
# Found 931 validated image filenames.
# [[1], [2], [0], [1], [3], [0], [3], [2], [0], [0], [2], [2], [4], [2], [1], [2], [2], [2], [3], [2], [4], [1], [3], [3], [5], [5], [0], [0], [2], [0], [3], [2], [0], [2], [5], [1], [3], [5], [5], [2], [5], [2], [2], [2], [4], [2], [2], [2], [2], [2], [5], [3], [2], [3], [4], [0, 1], [5], [2], [1], [2], [5], [2], [2], [1], [1], [5], [4], [1], [2], [0], [2], [0], [5], [4], [5], [0], [1], [1], [5], [5], [0], [3], [2], [0], [2], [4], [3], [2], [3], [3], [2], [4], [3], [5], [5], [2], [2], [1], [0, 1], [2], [0], [5], [2], [1], [5], [5], [2], [2], [2], [2], [1], [2], [2], [5], [2], [1], [0, 4], [2], [0], [3], [2], [4], [2], [1], [4], [5], [5], [5], [1], [2], [5], [5], [2], [4], [0], [5], [5], [2], [2], [2], [4], [2], [0, 4], [1], [1], [1], [2], [5], [4], [0], [4], [4], [2], [4], [2], [2], [5], [1], [3], [5], [3], [2], [3], [5], [5], [3], [2], [2], [2], [2], [1], [1], [2], [1], [1], [2], [2], [0, 5], [2], [1], [2], [1], [2], [2], [2], [2], [2], [2], [1], [5], [2], [1], [2], [1], [1], [4], [2], [1], [1], [2], [1], [0], [0], [5], [1], [1], [2], [5], [5], [1], [1], [2], [5], [2], [2], [1], [2], [2], [2], [1], [2], [1], [0], [1], [0], [0], [5], [0], [2], [1], [2], [5], [2], [2], [0], [4], [0], [0], [1], [5], [2], [2], [1, 4], [0], [2], [1, 4], [1], [2], [1], [2], [2], [2], [2], [2], [5], [1], [2], [2], [2], [1], [1], [5], [5], [4], [2], [2], [1], [5], [2], [1], [2], [4], [2], [2], [1], [5], [1], [5], [4], [2], [2], [2], [1], [4], [0], [2], [1], [0, 4], [0], [2], [5], [2], [1], [5], [1], [2], [2], [1], [0], [0], [4], [4], [2], [5], [2], [1], [2], [2], [2], [1], [0], [2], [2], [2], [2], [0], [5], [5], [2], [2], [5], [0], [2], [1], [2], [1], [2], [2], [1], [1], [2], [2], [0], [5], [4], [3], [0], [2], [1], [0], [1], [4], [4], [2], [2], [2], [1], [1], [2], [2], [0, 5], [5], [2], [5], [1], [2], [4], [2], [2], [2], [0], [0], [5], [2], [1], [5], [0], [4], [2], [1], [2], [0], [4], [1], [2], [2], [0, 1], [2], [1], [2], [1], [5], [0], [2], [1], [3], [5], [2], [5], [2], [0], [5], [0, 1, 4], [3], [2], [5], [5], [2], [2], [2], [2], [5], [2], [0], [1], [2], [5], [1], [4], [2], [2], [2], [1], [1], [5], [1], [5], [5], [1], [0, 1], [1], [2], [2], [0], [1], [2], [0, 5], [4], [1, 4], [2], [2], [5], [2], [2], [2], [1], [0, 5], [5], [2], [3], [0], [5], [4], [3], [3], [3], [2], [4], [5], [1], [2], [4], [0], [3], [2], [2], [1], [4], [1], [5], [2], [2], [5], [0], [2], [1], [2], [1], [2], [4], [4], [5], [5], [4], [2], [0], [2], [0, 4], [5], [2], [1], [3], [5], [2], [1], [5], [5], [2], [2], [5], [5], [3], [4], [1], [0], [5], [2], [5], [3], [1], [5], [1], [5], [1], [0, 5], [4], [5], [0, 4], [4], [5], [2], [1], [2], [2], [3], [1], [5], [5], [1], [2], [2], [1], [2], [1], [5], [0], [5], [2], [5], [2], [1], [0, 1], [5], [5], [0], [2], [0], [4], [3], [1], [0], [4], [5], [5], [5], [2], [4], [4], [4], [0, 4], [3], [1, 4], [5], [2], [1], [0, 1], [2], [1], [0], [5], [5], [0, 4], [0], [2], [2], [2], [2], [5], [2], [1], [1], [0, 4], [2], [4], [0, 4], [2], [1], [1], [5], [1], [5], [2], [2], [2], [2], [3], [4], [3], [3], [5], [5], [1], [5], [2], [4], [5], [1], [2], [5], [5], [2], [0], [1], [5], [2], [2], [2], [3], [2], [3], [2], [4], [5], [1, 4], [2], [2], [1], [2], [4], [3], [2], [4], [0], [2], [5], [5], [3], [0, 1], [2], [5], [4], [2], [2], [5], [5], [2], [1], [2], [2], [2], [4], [2], [5], [2], [2], [1], [5], [2], [2], [2], [2], [2], [2], [0, 1], [2], [2], [2], [4], [0], [2], [2], [2], [2], [5], [2], [1], [5], [2], [4], [2], [1], [4], [0], [2], [5], [0, 1], [5], [5], [0], [2], [0, 5], [1], [0], [2], [1], [0], [0], [4], [1], [2], [1], [2], [1], [5], [2], [1], [2], [3], [1], [1], [2], [5], [5], [1], [1], [1], [5], [5], [0, 4], [5], [5], [1], [2], [1], [2], [1], [5], [4], [0], [2], [1], [2], [4], [0], [5], [2], [5], [4], [2], [0], [2], [0, 1, 4], [0], [0], [2], [3], [2], [2], [2], [5], [2], [2], [1], [5], [1], [5], [2], [4], [2], [2], [5], [2], [5], [5], [1], [3], [0], [2], [4], [5], [5], [5], [1], [2], [2], [2], [0], [2], [2], [2], [2], [2], [2], [2], [1], [5], [1], [3], [0], [2 ...

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)

testlabels = []


for image in indices:
    temp = []
    for i in image:
        temp.append(str(labels[i]))
    testlabels.append(' '.join(temp))

print(testlabels)
# Out:
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
# ['frog_eye_leaf_spot', 'healthy', 'complex', 'frog_eye_leaf_spot', 'powdery_mildew', 'complex', 'powdery_mildew', 'healthy', 'complex', 'complex', 'healthy', 'healthy', 'rust', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'powdery_mildew', 'healthy', 'rust', 'frog_eye_leaf_spot', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab', 'complex', 'complex', 'healthy', 'complex', 'powdery_mildew', 'healthy', 'complex', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'healthy', 'healthy', 'rust', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'powdery_mildew', 'healthy', 'powdery_mildew', 'rust', 'complex frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'rust', 'frog_eye_leaf_spot', 'healthy', 'complex', 'healthy', 'complex', 'scab', 'rust', 'scab', 'complex', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'scab', 'complex', 'powdery_mildew', 'healthy', 'complex', 'healthy', 'rust', 'powdery_mildew', 'healthy', 'powdery_mildew', 'powdery_mildew', 'healthy', 'rust', 'powdery_mildew', 'scab', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'complex frog_eye_leaf_spot', 'healthy', 'complex', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab', 'healthy', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'scab', 'healthy', 'frog_eye_leaf_spot', 'complex rust', 'healthy', 'complex', 'powdery_mildew', 'healthy', 'rust', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'healthy', 'rust', 'complex', 'scab', 'scab', 'healthy', 'healthy', 'healthy', 'rust', 'healthy', 'complex rust', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'rust', 'complex', 'rust', 'rust', 'healthy', 'rust', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'powdery_mildew', 'scab', 'scab', 'powdery_mildew', 'healthy', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'complex scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'rust', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'complex', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'complex', 'complex', 'scab', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'complex', 'rust', 'complex', 'complex', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot rust', 'complex', 'healthy', 'frog_eye_leaf_spot rust', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'scab', 'rust', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'rust', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'rust', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'rust', 'complex', 'healthy', 'frog_eye_leaf_spot', 'complex rust', 'complex', 'healthy', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'complex', 'complex', 'rust', 'rust', 'healthy', 'scab', 'healthy', 'f ...

# %%
actuallabels = list(test['labels'])
print(actuallabels)
# Out:
# ['frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'complex', 'powdery_mildew', 'healthy', 'scab', 'complex', 'healthy', 'healthy', 'rust', 'scab', 'complex', 'scab', 'healthy', 'scab', 'powdery_mildew', 'healthy', 'rust', 'frog_eye_leaf_spot', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'healthy', 'complex', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'healthy', 'scab', 'rust', 'healthy', 'rust', 'powdery_mildew', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'rust', 'rust', 'complex', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'scab', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab', 'complex', 'rust', 'healthy', 'complex', 'healthy', 'complex', 'scab', 'rust', 'scab', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'rust', 'powdery_mildew', 'healthy', 'powdery_mildew', 'powdery_mildew', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'healthy', 'rust', 'scab', 'healthy', 'complex', 'scab', 'powdery_mildew', 'scab', 'healthy', 'scab', 'healthy', 'scab', 'complex', 'scab', 'complex', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'powdery_mildew complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'scab', 'rust', 'scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'complex', 'rust', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'rust', 'rust', 'rust', 'rust', 'healthy', 'rust', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'powdery_mildew', 'scab', 'scab', 'rust', 'healthy', 'scab frog_eye_leaf_spot complex', 'scab frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'healthy', 'healthy', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'rust', 'powdery_mildew', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot complex', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'scab', 'powdery_mildew complex', 'rust frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'rust', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'complex', 'scab', 'healthy', 'frog_eye_leaf_spot', 'rust', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'rust', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'rust', 'complex', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'rust complex', 'healthy', 'scab', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot comple ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(actuallabels,testlabels)
print(f"Test accuracy score: {accuracy}")
# Out:
# Test accuracy score: 0.6433941997851772

# %%
actual_test = pd.read_csv('sample_submission.csv')

# %%
actual_test_data = datagen.flow_from_dataframe(
    actual_test,
    directory = './actual_test_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (TARGET_SIZE,TARGET_SIZE),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

actual_preds = new_model.predict(actual_test_data)
print(actual_preds)
actual_preds = actual_preds.tolist()
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
threshold = {0: 0.26, # Complex
             5: 0.61, # scab
             1: 0.7, # frog eye leaf spot
             4: 0.5, # rust
             3: 0.5, # powdery mildew
             2: 0.3} #healthy

             
# Can set different threshold here
indices = []
for pred in actual_preds:
    temp = []
    for category in pred:
        if category>=threshold[pred.index(category)]: #assigning a different threshold to each disease
            temp.append(pred.index(category))
    if temp!=[]:
        pass
    else:
        temp.append(np.argmax(pred))
    # only add the predicted healthy labels, remove others
    if 2 in temp:
        temp = [2] # Resets the list 
    indices.append(temp)
    
print(indices)
# Out:
# Found 3 validated image filenames.
# [[0.16189021 0.13673183 0.04494947 0.00094032 0.19875106 0.17540175]
#  [0.43164748 0.70714927 0.00324035 0.00796545 0.13177463 0.1261608 ]
#  [0.1164467  0.34194568 0.10029685 0.00604817 0.07053971 0.08965161]]
# [[4], [0, 1], [1]]

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)

actualtestlabels = []


for image in indices:
    temp = []
    for i in image:
        temp.append(str(labels[i]))
    actualtestlabels.append(' '.join(temp))

print(actualtestlabels)
# Out:
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
# ['rust', 'complex frog_eye_leaf_spot', 'frog_eye_leaf_spot']

# %%
sub = pd.read_csv('./sample_submission.csv')
sub['labels'] = actualtestlabels
sub.to_csv('submission.csv', index=False)
sub
# Out:
#                   image                      labels
# 0  85f8cb619c66b863.jpg                        rust
# 1  ad8770db05586b59.jpg  complex frog_eye_leaf_spot
# 2  c7b03e718489f3ca.jpg          frog_eye_leaf_spot
