# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import PIL
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
from tqdm import tqdm
import tensorflow_addons as tfa
import random
from sklearn.preprocessing import MultiLabelBinarizer
from PIL import Image

pd.set_option("display.max_columns", None)

print('success')
# Out:
# success

# %% [markdown]
# ### Processing images
# #### Example taken from: https://www.kaggle.com/seyunhan/inceptionresnetv2-keras-pbl4
#
# We load the train,test,val images here

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train['labels'] = train['labels'].apply(lambda string: string.split(' '))
train
# Out:
#                       image                               labels
# 0      800113bb65efe69e.jpg                            [healthy]
# 1      8002cb321f8bfcdf.jpg  [scab, frog_eye_leaf_spot, complex]
# 2      80070f7fb5e2ccaa.jpg                               [scab]
# 3      80077517781fb94f.jpg                               [scab]
# 4      800cbf0ff87721f8.jpg                            [complex]
# ...                     ...                                  ...
# 17696  fffb900a92289a33.jpg                            [healthy]
# 17697  fffc488fa4c0e80c.jpg                               [scab]
# 17698  fffc94e092a59086.jpg                               [rust]
# 17699  fffe105cf6808292.jpg           [scab, frog_eye_leaf_spot]
# 17700  fffe472a0001bd25.jpg                            [healthy]
#
# [17701 rows x 2 columns]

# %%
s = list(train['labels'])
mlb = MultiLabelBinarizer()
trainx = pd.DataFrame(mlb.fit_transform(s), columns=mlb.classes_, index=train.index)
print(trainx.columns)
print(trainx.sum())

labels = list(trainx.sum().keys())
print(labels)
label_counts = trainx.sum().values.tolist()

fig, ax = plt.subplots(1,1, figsize=(20,6))

sns.barplot(x= labels, y= label_counts, ax=ax)
# Out:
# Index(['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust',
#        'scab'],
#       dtype='object')
# complex               2037
# frog_eye_leaf_spot    4139
# healthy               4396
# powdery_mildew        1210
# rust                  1963
# scab                  5435
# dtype: int64
# ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']
# <AxesSubplot:>

# %% [markdown]
# ### Viewing some images

# %%
fig1 = plt.figure(figsize=(26,10))

for i in range(1, 13):
    
    rand =  random.randrange(1, len(list(train['image'])))
    sample = os.path.join('./train_images/', train['image'][rand])
    
    img = Image.open(sample)
    
    ax = fig1.add_subplot(4,3,i)
    ax.imshow(img)
    
    title = f"{train['labels'][rand]}{img.size}"
    plt.title(title)
    
    fig1.tight_layout()

# %%
from keras.preprocessing.image import ImageDataGenerator

TARGET_SIZE = 256

datagen = ImageDataGenerator(rescale=1/255.0,
                            rotation_range=5,
                            zoom_range=0.1,
                            shear_range=0.05,
                            horizontal_flip=True,
                            validation_split=0.1)

train_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='training',
    x_col='image',
    y_col='labels',
    target_size=(TARGET_SIZE,TARGET_SIZE),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )

#'../input/plant-pathology-2021-fgvc8/train_images'
valid_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='validation',
    x_col='image',
    y_col='labels',
    target_size=(TARGET_SIZE,TARGET_SIZE),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )
# Out:
# Found 15931 validated image filenames belonging to 6 classes.
# Found 1770 validated image filenames belonging to 6 classes.

# %%
import h5py

# %%
seed = 1200
tf.random.set_seed(seed)

# weights_path = '../input/keras-pretrained-models/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5'
model = keras.applications.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# model = keras.applications.NASNetLarge(input_shape=(331, 331, 3), include_top=False, weights='imagenet', classes=1000)
print(model.input)
print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 5, 5, 1536), dtype=tf.float32, name=None), name='conv_7b_ac/Relu:0', description="created by layer 'conv_7b_ac'")

# %%
new_model = tf.keras.Sequential([
    model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(6, 
        kernel_initializer=keras.initializers.RandomUniform(seed=seed),
        bias_initializer=keras.initializers.Zeros(), name='dense_top', activation='sigmoid')
])

# Freezing the weights
for layer in new_model.layers[:-1]:
    layer.trainable=False
    
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 5, 5, 1536)       54336736
#  onal)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense_top (Dense)           (None, 6)                 9222
#
# =================================================================
# Total params: 54,345,958
# Trainable params: 9,222
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
## TO use CPU
CUDA_VISIBLE_DEVICES=""
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
print('success')
# Out:
# success

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))

# tf.config.experimental.set_memory_growth(
#     physical_devices[0], enable='True'
# )

# import PIL.Image
# Out:
# Num GPUs Available:  0

# %%
from tensorflow.keras.callbacks import EarlyStopping
import PIL
f1 = tfa.metrics.F1Score(num_classes=6,average='macro')

new_model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy',f1])
callbacks = keras.callbacks.EarlyStopping(monitor=f1, patience=4, mode='max', restore_best_weights=True)
history = new_model.fit_generator(generator=train_generator,
                    validation_data=valid_generator,
                    epochs=65,
                    steps_per_epoch=train_generator.samples//256, # = 58
                    validation_steps=valid_generator.samples//128,
                    callbacks=callbacks)
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_36784\3583829206.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = new_model.fit_generator(generator=train_generator,
# Epoch 1/65
# 62/62 [==============================] - ETA: 0s - loss: 0.4446 - accuracy: 0.3498 - f1_score: 0.2472WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 250s 4s/step - loss: 0.4446 - accuracy: 0.3498 - f1_score: 0.2472 - val_loss: 0.3933 - val_accuracy: 0.4399 - val_f1_score: 0.3503
# Epoch 2/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.4899 - f1_score: 0.4380WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 250s 4s/step - loss: 0.3759 - accuracy: 0.4899 - f1_score: 0.4380 - val_loss: 0.3711 - val_accuracy: 0.4543 - val_f1_score: 0.4279
# Epoch 3/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.5126 - f1_score: 0.4525WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 227s 4s/step - loss: 0.3622 - accuracy: 0.5126 - f1_score: 0.4525 - val_loss: 0.3328 - val_accuracy: 0.5625 - val_f1_score: 0.4589
# Epoch 4/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3458 - accuracy: 0.5413 - f1_score: 0.4918WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 242s 4s/step - loss: 0.3458 - accuracy: 0.5413 - f1_score: 0.4918 - val_loss: 0.3369 - val_accuracy: 0.5409 - val_f1_score: 0.4860
# Epoch 5/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3370 - accuracy: 0.5494 - f1_score: 0.5089WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 239s 4s/step - loss: 0.3370 - accuracy: 0.5494 - f1_score: 0.5089 - val_loss: 0.3377 - val_accuracy: 0.5288 - val_f1_score: 0.4739
# Epoch 6/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3321 - accuracy: 0.5469 - f1_score: 0.5169WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 239s 4s/step - loss: 0.3321 - accuracy: 0.5469 - f1_score: 0.5169 - val_loss: 0.3130 - val_accuracy: 0.5962 - val_f1_score: 0.5679
# Epoch 7/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.5993 - f1_score: 0.5505WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 253s 4s/step - loss: 0.3217 - accuracy: 0.5993 - f1_score: 0.5505 - val_loss: 0.3089 - val_accuracy: 0.6130 - val_f1_score: 0.5746
# Epoch 8/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.5968 - f1_score: 0.5547WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 236s 4s/step - loss: 0.3160 - accuracy: 0.5968 - f1_score: 0.5547 - val_loss: 0.3063 - val_accuracy: 0.5889 - val_f1_score: 0.5362
# Epoch 9/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.6008 - f1_score: 0.5583WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] -
ARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 222s 4s/step - loss: 0.2747 - accuracy: 0.6744 - f1_score: 0.6342 - val_loss: 0.2295 - val_accuracy: 0.7428 - val_f1_score: 0.6880
# Epoch 57/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.6825 - f1_score: 0.6514WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 220s 4s/step - loss: 0.2710 - accuracy: 0.6825 - f1_score: 0.6514 - val_loss: 0.2544 - val_accuracy: 0.7019 - val_f1_score: 0.6586
# Epoch 58/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.6699 - f1_score: 0.6315WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 221s 4s/step - loss: 0.2717 - accuracy: 0.6699 - f1_score: 0.6315 - val_loss: 0.2517 - val_accuracy: 0.6851 - val_f1_score: 0.6300
# Epoch 59/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.6726 - f1_score: 0.6398WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 218s 4s/step - loss: 0.2791 - accuracy: 0.6726 - f1_score: 0.6398 - val_loss: 0.2329 - val_accuracy: 0.7404 - val_f1_score: 0.6900
# Epoch 60/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.6895 - f1_score: 0.6471WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 221s 4s/step - loss: 0.2704 - accuracy: 0.6895 - f1_score: 0.6471 - val_loss: 0.2446 - val_accuracy: 0.7236 - val_f1_score: 0.6564
# Epoch 61/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.6769 - f1_score: 0.6471WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 219s 4s/step - loss: 0.2740 - accuracy: 0.6769 - f1_score: 0.6471 - val_loss: 0.2436 - val_accuracy: 0.7212 - val_f1_score: 0.6476
# Epoch 62/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2645 - accuracy: 0.6905 - f1_score: 0.6587WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 221s 4s/step - loss: 0.2645 - accuracy: 0.6905 - f1_score: 0.6587 - val_loss: 0.2543 - val_accuracy: 0.7115 - val_f1_score: 0.6832
# Epoch 63/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.6799 - f1_score: 0.6656WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 220s 4s/step - loss: 0.2736 - accuracy: 0.6799 - f1_score: 0.6656 - val_loss: 0.2529 - val_accuracy: 0.6851 - val_f1_score: 0.6644
# Epoch 64/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.6678 - f1_score: 0.6382WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 221s 4s/step - loss: 0.2768 - accuracy: 0.6678 - f1_score: 0.6382 - val_loss: 0.2586 - val_accuracy: 0.7163 - val_f1_score: 0.6800
# Epoch 65/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.6613 - f1_score: 0.6334WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 219s 4s/step - loss: 0.2778 - accuracy: 0.6613 - f1_score: 0.6334 - val_loss: 0.2544 - val_accuracy: 0.7043 - val_f1_score: 0.6563

# %% [markdown]
# ## Making predictions

# %%
for img_name in tqdm(test['image']):
    path = './test_images/'+str(img_name)
    with PIL.Image.open(path) as img:
        img = img.resize((256,256))
        img.save(f'./test_size256_images/{img_name}')
# Out:
# 100%|██████████| 931/931 [01:22<00:00, 11.35it/s]

# %%
test_data = datagen.flow_from_dataframe(
    test,
    directory = './test_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (TARGET_SIZE,TARGET_SIZE),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

preds = new_model.predict(test_data)
preds = preds.tolist()

# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
threshold = {0: 0.26, # Complex
             5: 0.61, # scab
             1: 0.7, # frog eye leaf spot
             4: 0.5, # rust
             3: 0.5, # powdery mildew
             2: 0.3} #healthy

             
# Can set different threshold here
indices = []
for pred in preds:
    temp = []
    for category in pred:
        if category>=threshold[pred.index(category)]: #assigning a different threshold to each disease
            temp.append(pred.index(category))
    if temp!=[]:
        pass
    else:
        temp.append(np.argmax(pred))
    # only add the predicted healthy labels, remove others
    if 2 in temp:
        temp = [2] # Resets the list 
    indices.append(temp)
    
    
print(indices)
# Out:
# Found 931 validated image filenames.
 'scab', 'healthy', 'scab', 'powdery_mildew', 'healthy', 'rust', 'frog_eye_leaf_spot', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'healthy', 'complex', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'healthy', 'scab', 'rust', 'healthy', 'rust', 'powdery_mildew', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'rust', 'rust', 'complex', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'scab', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab', 'complex', 'rust', 'healthy', 'complex', 'healthy', 'complex', 'scab', 'rust', 'scab', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'rust', 'powdery_mildew', 'healthy', 'powdery_mildew', 'powdery_mildew', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'healthy', 'rust', 'scab', 'healthy', 'complex', 'scab', 'powdery_mildew', 'scab', 'healthy', 'scab', 'healthy', 'scab', 'complex', 'scab', 'complex', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'powdery_mildew complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'scab', 'rust', 'scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'complex', 'rust', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'rust', 'rust', 'rust', 'rust', 'healthy', 'rust', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'powdery_mildew', 'scab', 'scab', 'rust', 'healthy', 'scab frog_eye_leaf_spot complex', 'scab frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'healthy', 'healthy', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'rust', 'powdery_mildew', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot complex', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'scab', 'powdery_mildew complex', 'rust frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'rust', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'complex', 'scab', 'healthy', 'frog_eye_leaf_spot', 'rust', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'rust', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'rust', 'complex', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'rust complex', 'healthy', 'scab', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot comple ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(actuallabels,testlabels)
print(f"Test accuracy score: {accuracy}")
# Out:
# Test accuracy score: 0.6455424274973147

# %%
actual_test = pd.read_csv('sample_submission.csv')

# %%
actual_test_data = datagen.flow_from_dataframe(
    actual_test,
    directory = './actual_test_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (TARGET_SIZE,TARGET_SIZE),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

actual_preds = new_model.predict(actual_test_data)
print(actual_preds)
actual_preds = actual_preds.tolist()
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
threshold = {0: 0.26, # Complex
             5: 0.61, # scab
             1: 0.7, # frog eye leaf spot
             4: 0.5, # rust
             3: 0.5, # powdery mildew
             2: 0.3} #healthy

             
# Can set different threshold here
indices = []
for pred in actual_preds:
    temp = []
    for category in pred:
        if category>=threshold[pred.index(category)]: #assigning a different threshold to each disease
            temp.append(pred.index(category))
    if temp!=[]:
        pass
    else:
        temp.append(np.argmax(pred))
    # only add the predicted healthy labels, remove others
    if 2 in temp:
        temp = [2] # Resets the list 
    indices.append(temp)
    
print(indices)
# Out:
# Found 3 validated image filenames.
# [[1.52573109e-01 1.35619193e-01 1.84467435e-03 1.54048204e-04
#   6.66213036e-03 7.08434105e-01]
#  [4.42166656e-01 6.17920995e-01 2.32112408e-03 1.28337741e-03
#   1.06577784e-01 3.88206184e-01]
#  [7.19715059e-02 5.07148921e-01 6.56884909e-03 2.22024322e-03
#   6.50638640e-02 2.29798257e-01]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\riley\Desktop\SUTD stuff\Term 7 (ISTD Senior)\50.035 Computer Vision\Project\InceptionNet_Riley v2.ipynb Cell 22' in <cell line: 29>()
#      <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000021?line=29'>30</a> temp = []
#      <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000021?line=30'>31</a> for category in actual_preds:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000021?line=31'>32</a>     if category>=threshold[pred.index(category)]: #assigning a different threshold to each disease
#      <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000021?line=32'>33</a>         temp.append(pred.index(category))
#      <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000021?line=33'>34</a> if temp!=[]:
#
# ValueError: [0.1525731086730957, 0.13561919331550598, 0.0018446743488311768, 0.00015404820442199707, 0.006662130355834961, 0.7084341049194336] is not in list

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)

actualtestlabels = []


for image in indices:
    temp = []
    for i in image:
        temp.append(str(labels[i]))
    actualtestlabels.append(' '.join(temp))

print(actualtestlabels)
# Out:
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
# ['complex frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'complex frog_eye_leaf_spot', 'powdery_mildew scab', 'complex scab', 'powdery_mildew', 'healthy', 'complex scab', 'rust', 'healthy', 'scab', 'complex rust', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'powdery_mildew', 'healthy', 'rust', 'scab', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab', 'complex frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'healthy', 'complex', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'healthy', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'scab', 'healthy', 'scab', 'scab', 'healthy', 'scab', 'powdery_mildew', 'healthy', 'scab', 'rust', 'complex frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab', 'healthy', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'complex scab', 'scab', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'powdery_mildew', 'scab', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab', 'powdery_mildew', 'powdery_mildew', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'rust', 'scab', 'healthy', 'complex frog_eye_leaf_spot', 'complex scab', 'scab', 'scab', 'scab', 'scab', 'healthy', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'healthy', 'rust', 'scab', 'scab', 'powdery_mildew', 'healthy', 'rust', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'healthy', 'rust', 'complex scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'healthy', 'rust', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'healthy', 'scab', 'rust', 'complex', 'rust', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'healthy', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'healthy', 'scab', 'scab', 'rust', 'scab', 'complex', 'scab', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'complex scab', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'rust', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'complex', 'scab', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab', 'complex', 'complex', 'scab', 'scab', 'scab', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'scab', 'scab', 'rust', 'scab', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'complex scab', 'scab', 'rust', 'scab', 'healthy', 'scab', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'scab', 'rust', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'rust', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'rust', 'scab', 'scab', 'healthy', 'frog_eye_leaf_spot', 'rust', 'complex', 'healthy', 'frog_eye_leaf_spot', 'complex rust', 'scab', 'healthy', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'rust', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'scab', 'complex scab', 'healthy', 'healthy', 'scab', 'scab', 'complex scab', 'scab', 'complex scab', 'complex', 'scab', 'scab', 'scab', ...

# %%
sub = pd.read_csv('./sample_submission.csv')
sub['labels'] = actualtestlabels
sub.to_csv('submission.csv', index=False)
sub
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\riley\Desktop\SUTD stuff\Term 7 (ISTD Senior)\50.035 Computer Vision\Project\InceptionNet_Riley v2.ipynb Cell 24' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000023?line=0'>1</a> sub = pd.read_csv('./sample_submission.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000023?line=1'>2</a> sub['labels'] = actualtestlabels
#       <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000023?line=2'>3</a> sub.to_csv('submission.csv', index=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/riley/Desktop/SUTD%20stuff/Term%207%20%28ISTD%20Senior%29/50.035%20Computer%20Vision/Project/InceptionNet_Riley%20v2.ipynb#ch0000023?line=3'>4</a> sub
#
# File ~\anaconda3\envs\cv\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3651'>3652</a>     self._setitem_array([key], value)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3652'>3653</a> else:
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3653'>3654</a>     # set column
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3654'>3655</a>     self._set_item(key, value)
#
# File ~\anaconda3\envs\cv\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3821'>3822</a> def _set_item(self, key, value) -> None:
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3822'>3823</a>     """
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3823'>3824</a>     Add series to DataFrame in specified column.
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3824'>3825</a>
#    (...)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3829'>3830</a>     ensure homogeneity.
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3830'>3831</a>     """
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3831'>3832</a>     value = self._sanitize_column(value)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3833'>3834</a>     if (
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3834'>3835</a>         key in self.columns
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3835'>3836</a>         and value.ndim == 1
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3836'>3837</a>         and not is_extension_array_dtype(value)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3837'>3838</a>     ):
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3838'>3839</a>         # broadcast across multiple columns if necessary
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=3839'>3840</a>         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\envs\cv\lib\site-packages\pandas\core\frame.py:4529, in DataFrame._sanitize_column(self, value)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=4525'>4526</a>     return _reindex_for_setitem(value, self.index)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=4527'>4528</a> if is_list_like(value):
# -> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=4528'>4529</a>     com.require_length_match(value, self.index)
#    <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/frame.py?line=4529'>4530</a> return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\envs\cv\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=552'>553</a> """
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=553'>554</a> Check the length of data matches the length of the index.
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=554'>555</a> """
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=555'>556</a> if len(data) != len(index):
# --> <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=556'>557</a>     raise ValueError(
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=557'>558</a>         "Length of values "
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=558'>559</a>         f"({len(data)}) "
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=559'>560</a>         "does not match length of index "
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=560'>561</a>         f"({len(index)})"
#     <a href='file:///c%3A/Users/riley/anaconda3/envs/cv/lib/site-packages/pandas/core/common.py?line=561'>562</a>     )
#
# ValueError: Length of values (931) does not match length of index (3)
