# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import PIL
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
from tqdm import tqdm
import tensorflow_addons as tfa
import random
from sklearn.preprocessing import MultiLabelBinarizer
from PIL import Image

pd.set_option("display.max_columns", None)

print('success')
# Out:
# success

# %% [markdown]
# ### Processing images
# #### Example taken from: https://www.kaggle.com/seyunhan/inceptionresnetv2-keras-pbl4
#
# We load the train,test,val images here

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train['labels'] = train['labels'].apply(lambda string: string.split(' '))
train
# Out:
#                       image                               labels
# 0      800113bb65efe69e.jpg                            [healthy]
# 1      8002cb321f8bfcdf.jpg  [scab, frog_eye_leaf_spot, complex]
# 2      80070f7fb5e2ccaa.jpg                               [scab]
# 3      80077517781fb94f.jpg                               [scab]
# 4      800cbf0ff87721f8.jpg                            [complex]
# ...                     ...                                  ...
# 17696  fffb900a92289a33.jpg                            [healthy]
# 17697  fffc488fa4c0e80c.jpg                               [scab]
# 17698  fffc94e092a59086.jpg                               [rust]
# 17699  fffe105cf6808292.jpg           [scab, frog_eye_leaf_spot]
# 17700  fffe472a0001bd25.jpg                            [healthy]
#
# [17701 rows x 2 columns]

# %%
s = list(train['labels'])
mlb = MultiLabelBinarizer()
trainx = pd.DataFrame(mlb.fit_transform(s), columns=mlb.classes_, index=train.index)
print(trainx.columns)
print(trainx.sum())

labels = list(trainx.sum().keys())
print(labels)
label_counts = trainx.sum().values.tolist()

fig, ax = plt.subplots(1,1, figsize=(20,6))

sns.barplot(x= labels, y= label_counts, ax=ax)
# Out:
# Index(['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust',
#        'scab'],
#       dtype='object')
# complex               2037
# frog_eye_leaf_spot    4139
# healthy               4396
# powdery_mildew        1210
# rust                  1963
# scab                  5435
# dtype: int64
# ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']
# <AxesSubplot:>

# %% [markdown]
# ### Viewing some images

# %%
fig1 = plt.figure(figsize=(26,10))

for i in range(1, 13):
    
    rand =  random.randrange(1, len(list(train['image'])))
    sample = os.path.join('./train_images/', train['image'][rand])
    
    img = Image.open(sample)
    
    ax = fig1.add_subplot(4,3,i)
    ax.imshow(img)
    
    title = f"{train['labels'][rand]}{img.size}"
    plt.title(title)
    
    fig1.tight_layout()

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1/255.0,
                            rotation_range=5,
                            zoom_range=0.1,
                            shear_range=0.05,
                            horizontal_flip=True,
                            validation_split=0.1)

train_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='training',
    x_col='image',
    y_col='labels',
    target_size=(224,224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )

#'../input/plant-pathology-2021-fgvc8/train_images'
valid_generator = datagen.flow_from_dataframe(
    train,
    directory='./train_images',
    subset='validation',
    x_col='image',
    y_col='labels',
    target_size=(224,224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=444
    )
# Out:
# Found 15931 validated image filenames belonging to 6 classes.
# Found 1770 validated image filenames belonging to 6 classes.

# %%
import h5py

# %%
seed = 1200
tf.random.set_seed(seed)

# weights_path = '../input/keras-pretrained-models/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5'
model = keras.applications.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# model = keras.applications.NASNetLarge(input_shape=(331, 331, 3), include_top=False, weights='imagenet', classes=1000)
print(model.input)
print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 5, 5, 1536), dtype=tf.float32, name=None), name='conv_7b_ac/Relu:0', description="created by layer 'conv_7b_ac'")

# %%
new_model = tf.keras.Sequential([
    model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(6, 
        kernel_initializer=keras.initializers.RandomUniform(seed=seed),
        bias_initializer=keras.initializers.Zeros(), name='dense_top', activation='sigmoid')
])

# Freezing the weights
for layer in new_model.layers[:-1]:
    layer.trainable=False
    
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 5, 5, 1536)       54336736
#  onal)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dense_top (Dense)           (None, 6)                 9222
#
# =================================================================
# Total params: 54,345,958
# Trainable params: 9,222
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
## TO use CPU
CUDA_VISIBLE_DEVICES=""
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
print('success')
# Out:
# success

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))

# tf.config.experimental.set_memory_growth(
#     physical_devices[0], enable='True'
# )

# import PIL.Image
# Out:
# Num GPUs Available:  0

# %%
from tensorflow.keras.callbacks import EarlyStopping
import PIL
f1 = tfa.metrics.F1Score(num_classes=6,average='macro')

new_model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy',f1])
callbacks = keras.callbacks.EarlyStopping(monitor=f1, patience=4, mode='max', restore_best_weights=True)
history = new_model.fit_generator(generator=train_generator,
                    validation_data=valid_generator,
                    epochs=65,
                    steps_per_epoch=train_generator.samples//256, # = 58
                    validation_steps=valid_generator.samples//128,
                    callbacks=callbacks)
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_8344\3583829206.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = new_model.fit_generator(generator=train_generator,
# Epoch 1/65
# 62/62 [==============================] - ETA: 0s - loss: 0.4454 - accuracy: 0.3468 - f1_score: 0.2745WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 232s 4s/step - loss: 0.4454 - accuracy: 0.3468 - f1_score: 0.2745 - val_loss: 0.3796 - val_accuracy: 0.4904 - val_f1_score: 0.4316
# Epoch 2/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3730 - accuracy: 0.4907 - f1_score: 0.4442WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 198s 3s/step - loss: 0.3730 - accuracy: 0.4907 - f1_score: 0.4442 - val_loss: 0.3541 - val_accuracy: 0.5240 - val_f1_score: 0.4618
# Epoch 3/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.5459 - f1_score: 0.4980WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 200s 3s/step - loss: 0.3402 - accuracy: 0.5459 - f1_score: 0.4980 - val_loss: 0.3382 - val_accuracy: 0.5192 - val_f1_score: 0.4423
# Epoch 4/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.5559 - f1_score: 0.4987WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 194s 3s/step - loss: 0.3350 - accuracy: 0.5559 - f1_score: 0.4987 - val_loss: 0.3225 - val_accuracy: 0.5697 - val_f1_score: 0.5060
# Epoch 5/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.5514 - f1_score: 0.5061WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 196s 3s/step - loss: 0.3317 - accuracy: 0.5514 - f1_score: 0.5061 - val_loss: 0.3289 - val_accuracy: 0.5433 - val_f1_score: 0.4821
# Epoch 6/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.5927 - f1_score: 0.5308WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 196s 3s/step - loss: 0.3180 - accuracy: 0.5927 - f1_score: 0.5308 - val_loss: 0.3104 - val_accuracy: 0.5889 - val_f1_score: 0.5110
# Epoch 7/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.5943 - f1_score: 0.5514WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 197s 3s/step - loss: 0.3114 - accuracy: 0.5943 - f1_score: 0.5514 - val_loss: 0.2960 - val_accuracy: 0.6274 - val_f1_score: 0.5757
# Epoch 8/65
# 62/62 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.6119 - f1_score: 0.5558WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 197s 3s/step - loss: 0.3097 - accuracy: 0.6119 - f1_score: 0.5558 - val_loss: 0.3083 - val_accuracy: 0.5938 - val_f1_score: 0.5458
# Epoch 9/65
# 62/62 [==============================] - ETA: 0s - loss: 0.
65
# 62/62 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.6705 - f1_score: 0.6251WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 193s 3s/step - loss: 0.2805 - accuracy: 0.6705 - f1_score: 0.6251 - val_loss: 0.2669 - val_accuracy: 0.6995 - val_f1_score: 0.6763
# Epoch 25/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.6779 - f1_score: 0.6354WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 194s 3s/step - loss: 0.2704 - accuracy: 0.6779 - f1_score: 0.6354 - val_loss: 0.2860 - val_accuracy: 0.6851 - val_f1_score: 0.6681
# Epoch 26/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.6769 - f1_score: 0.6236WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 195s 3s/step - loss: 0.2700 - accuracy: 0.6769 - f1_score: 0.6236 - val_loss: 0.2630 - val_accuracy: 0.6779 - val_f1_score: 0.6350
# Epoch 27/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.6628 - f1_score: 0.6280WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 195s 3s/step - loss: 0.2753 - accuracy: 0.6628 - f1_score: 0.6280 - val_loss: 0.2624 - val_accuracy: 0.6755 - val_f1_score: 0.6151
# Epoch 28/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.6820 - f1_score: 0.6292WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 195s 3s/step - loss: 0.2708 - accuracy: 0.6820 - f1_score: 0.6292 - val_loss: 0.2606 - val_accuracy: 0.7115 - val_f1_score: 0.6359
# Epoch 29/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2773 - accuracy: 0.6699 - f1_score: 0.6436WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 197s 3s/step - loss: 0.2773 - accuracy: 0.6699 - f1_score: 0.6436 - val_loss: 0.2701 - val_accuracy: 0.6779 - val_f1_score: 0.6004
# Epoch 30/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2719 - accuracy: 0.6804 - f1_score: 0.6455WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 196s 3s/step - loss: 0.2719 - accuracy: 0.6804 - f1_score: 0.6455 - val_loss: 0.2612 - val_accuracy: 0.7284 - val_f1_score: 0.7293
# Epoch 31/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.6865 - f1_score: 0.6638WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 197s 3s/step - loss: 0.2600 - accuracy: 0.6865 - f1_score: 0.6638 - val_loss: 0.2430 - val_accuracy: 0.7260 - val_f1_score: 0.6933
# Epoch 32/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2615 - accuracy: 0.6935 - f1_score: 0.6474WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 204s 3s/step - loss: 0.2615 - accuracy: 0.6935 - f1_score: 0.6474 - val_loss: 0.2630 - val_accuracy: 0.6562 - val_f1_score: 0.6147
# Epoch 33/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2759 - accuracy: 0.6769 - f1_score: 0.6425WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 198s 3s/step - loss: 0.2759 - accuracy: 0.6769 - f1_score: 0.6425 - val_loss: 0.2594 - val_accuracy: 0.6731 - val_f1_score: 0.6449
# Epoch 34/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.6850 - f1_score: 0.6523WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 197s 3s/step - loss: 0.2621 - accuracy: 0.6850 - f1_score: 0.6523 - val_loss: 0.2579 - val_accuracy: 0.7212 - val_f1_score: 0.6827
# Epoch 35/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.6910 - f1_score: 0.6517WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 202s 3s/step - loss: 0.2599 - accuracy: 0.6910 - f1_score: 0.6517 - val_loss: 0.2620 - val_accuracy: 0.6803 - val_f1_score: 0.6284
# Epoch 36/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.6744 - f1_score: 0.6395WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 199s 3s/step - loss: 0.2692 - accuracy: 0.6744 - f1_score: 0.6395 - val_loss: 0.2595 - val_accuracy: 0.6779 - val_f1_score: 0.6472
# Epoch 37/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.6835 - f1_score: 0.6514WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 203s 3s/step - loss: 0.2635 - accuracy: 0.6835 - f1_score: 0.6514 - val_loss: 0.2720 - val_accuracy: 0.6538 - val_f1_score: 0.6157
# Epoch 38/65
# 62/62 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0
65
# 62/62 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.7077 - f1_score: 0.6725WARNING:tensorflow:Early stopping conditioned on metric `F1Score(name=f1_score,dtype=float32,num_classes=6,average=macro,threshold=None)` which is not available. Available metrics are: loss,accuracy,f1_score,val_loss,val_accuracy,val_f1_score
# 62/62 [==============================] - 187s 3s/step - loss: 0.2490 - accuracy: 0.7077 - f1_score: 0.6725 - val_loss: 0.2619 - val_accuracy: 0.6971 - val_f1_score: 0.6630

# %% [markdown]
# ## Making predictions

# %%
for img_name in tqdm(test['image']):
    path = './test_images/'+str(img_name)
    with PIL.Image.open(path) as img:
        img = img.resize((256,256))
        img.save(f'./test_size256_images/{img_name}')
# Out:
# 100%|██████████| 931/931 [01:25<00:00, 10.95it/s]

# %%
test_data = datagen.flow_from_dataframe(
    test,
    directory = './test_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (256,256),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

preds = new_model.predict(test_data)
preds = preds.tolist()

indices = []
for pred in preds:
    temp = []
    for category in pred:
        if category>=0.3:
            temp.append(pred.index(category))
    if temp!=[]:
        pass
    else:
        temp.append(np.argmax(pred))
    # only add the predicted healthy labels, remove others
    if 2 in temp:
        temp = [2] # Resets the list 
    indices.append(temp)
    
    
print(indices)
# Out:
# Found 931 validated image filenames.
# [[1], [1, 5], [1, 5], [0, 1], [3, 5], [0, 1, 5], [3], [2], [0, 5], [4], [2], [5], [0, 4], [1, 5], [1], [5], [2], [2], [3], [2], [1, 4], [1, 5], [3], [3], [2], [5], [0, 1, 4], [3, 5], [2], [0, 1, 5], [3], [2], [0, 1, 5], [2], [5], [1], [3], [5], [5], [5], [5], [5], [2], [2], [4], [2], [1, 4], [5], [5], [2], [5], [3], [5], [5], [4], [0, 1], [1, 5], [5], [1], [5], [5], [2], [3], [1], [1, 5], [5], [5], [4], [2], [0, 1], [2], [0, 5], [5], [4, 5], [5], [1], [1, 4], [0, 1], [5], [5], [1, 5], [3], [5], [5], [2], [1], [3, 5], [1], [3], [3], [5], [1], [3], [5], [5], [1, 5], [5], [1], [1], [2], [4], [5], [2], [0, 1, 5], [0, 5], [5], [5], [5], [5], [2], [5], [0], [2], [3, 5], [2], [5], [4], [5], [5], [3], [2], [4], [2], [1], [1, 4], [2], [5], [5], [1, 5], [2], [5], [5], [2], [4], [0, 5], [5], [5], [5], [2], [2], [4], [2], [4], [1], [1, 4], [5], [2], [5], [4], [0, 1, 4], [4], [4], [2], [1, 4], [2], [5], [5], [1], [3], [5], [3], [2], [2], [1, 5], [2], [1, 4], [2], [0, 1], [5], [0, 1], [1, 5], [1], [2], [1], [1], [5], [2], [0, 5], [2], [0, 1], [1], [0, 1, 5], [2], [2], [2], [2], [2], [0], [0, 1], [5], [2], [1], [2], [1], [1], [4, 5], [2], [1], [1], [2], [1], [0, 5], [0, 1], [5], [1], [1], [2], [5], [5], [1], [1], [2], [5], [2], [2], [5], [2], [1], [2], [1, 4], [5], [1, 5], [0, 1, 4], [0, 1], [0, 5], [5], [1, 5], [0, 1], [2], [1], [2], [0, 1, 5], [2], [5], [5], [4], [5], [0, 1], [1], [5], [5], [5], [1, 4], [0, 1, 5], [5], [1, 4], [5], [2], [1, 5], [2], [2], [2],
, 4], [2], [2], [5], [5], [5], [1], [2], [2], [2], [4], [2], [0, 1, 5], [2], [5], [1, 4], [5], [2], [2], [5], [2], [2], [2], [1], [5], [2], [2], [4, 5], [0, 1, 5], [2], [2], [2], [5], [5], [2], [1], [1, 5], [2], [1, 4], [1], [1], [4], [0, 5], [5], [5], [1], [5], [5], [0, 5], [2], [0, 5], [0, 1, 5], [5], [2 ...

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)

testlabels = []


for image in indices:
    temp = []
    for i in image:
        temp.append(str(labels[i]))
    testlabels.append(' '.join(temp))

print(testlabels)
# Out:
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
# ['frog_eye_leaf_spot', 'frog_eye_leaf_spot scab', 'frog_eye_leaf_spot scab', 'complex frog_eye_leaf_spot', 'powdery_mildew scab', 'complex frog_eye_leaf_spot scab', 'powdery_mildew', 'healthy', 'complex scab', 'rust', 'healthy', 'scab', 'complex rust', 'frog_eye_leaf_spot scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'powdery_mildew', 'healthy', 'frog_eye_leaf_spot rust', 'frog_eye_leaf_spot scab', 'powdery_mildew', 'powdery_mildew', 'healthy', 'scab', 'complex frog_eye_leaf_spot rust', 'powdery_mildew scab', 'healthy', 'complex frog_eye_leaf_spot scab', 'powdery_mildew', 'healthy', 'complex frog_eye_leaf_spot scab', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'healthy', 'frog_eye_leaf_spot rust', 'scab', 'scab', 'healthy', 'scab', 'powdery_mildew', 'scab', 'scab', 'rust', 'complex frog_eye_leaf_spot', 'frog_eye_leaf_spot scab', 'scab', 'frog_eye_leaf_spot', 'scab', 'scab', 'healthy', 'powdery_mildew', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot scab', 'scab', 'scab', 'rust', 'healthy', 'complex frog_eye_leaf_spot', 'healthy', 'complex scab', 'scab', 'rust scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot rust', 'complex frog_eye_leaf_spot', 'scab', 'scab', 'frog_eye_leaf_spot scab', 'powdery_mildew', 'scab', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'powdery_mildew', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'frog_eye_leaf_spot scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'rust', 'scab', 'healthy', 'complex frog_eye_leaf_spot scab', 'complex scab', 'scab', 'scab', 'scab', 'scab', 'healthy', 'scab', 'complex', 'healthy', 'powdery_mildew scab', 'healthy', 'scab', 'rust', 'scab', 'scab', 'powdery_mildew', 'healthy', 'rust', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot rust', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot scab', 'healthy', 'scab', 'scab', 'healthy', 'rust', 'complex scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'healthy', 'rust', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot rust', 'scab', 'healthy', 'scab', 'rust', 'complex frog_eye_leaf_spot rust', 'rust', 'rust', 'healthy', 'frog_eye_leaf_spot rust', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'healthy', 'frog_eye_leaf_spot scab', 'healthy', 'frog_eye_leaf_spot rust', 'healthy', 'complex frog_eye_leaf_spot', 'scab', 'complex frog_eye_leaf_spot', 'frog_eye_leaf_spot scab', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'healthy', 'complex scab', 'healthy', 'complex frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex frog_eye_leaf_spot scab', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'complex', 'complex frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'rust scab', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex scab', 'complex frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot rust', 'scab', 'frog_eye_leaf_spot scab', 'complex frog_eye_leaf_spot rust', 'complex frog_eye_leaf_spot', 'complex scab', 'scab', 'frog_eye_leaf_spot scab', 'complex frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'complex frog_eye_leaf_spot scab', 'healthy', 'scab', 'scab', 'rust', 'scab', 'complex frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot rust', 'complex frog_eye_leaf_spot scab', 'scab', 'frog_eye_leaf_spot rust', 'scab', 'healthy', 'frog_eye_leaf_spot scab', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy' ...

# %%
actuallabels = list(test['labels'])
print(actuallabels)
# Out:
# ['frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'complex', 'powdery_mildew', 'healthy', 'scab', 'complex', 'healthy', 'healthy', 'rust', 'scab', 'complex', 'scab', 'healthy', 'scab', 'powdery_mildew', 'healthy', 'rust', 'frog_eye_leaf_spot', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'healthy', 'complex', 'healthy', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'scab', 'healthy', 'scab', 'healthy', 'healthy', 'scab', 'rust', 'healthy', 'rust', 'powdery_mildew', 'scab', 'healthy', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'rust', 'rust', 'complex', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'scab', 'scab', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab', 'complex', 'rust', 'healthy', 'complex', 'healthy', 'complex', 'scab', 'rust', 'scab', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'powdery_mildew', 'powdery_mildew', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'rust', 'powdery_mildew', 'healthy', 'powdery_mildew', 'powdery_mildew', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'healthy', 'rust', 'scab', 'healthy', 'complex', 'scab', 'powdery_mildew', 'scab', 'healthy', 'scab', 'healthy', 'scab', 'complex', 'scab', 'complex', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'powdery_mildew complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'scab', 'rust', 'scab', 'scab', 'scab', 'scab', 'healthy', 'healthy', 'rust', 'complex', 'rust', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'rust', 'rust', 'rust', 'rust', 'healthy', 'rust', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'powdery_mildew', 'scab', 'powdery_mildew', 'healthy', 'powdery_mildew', 'scab', 'scab', 'rust', 'healthy', 'scab frog_eye_leaf_spot complex', 'scab frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'healthy', 'healthy', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'scab', 'scab frog_eye_leaf_spot', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'rust', 'powdery_mildew', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot complex', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab frog_eye_leaf_spot', 'healthy', 'scab', 'scab', 'frog_eye_leaf_spot', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'healthy', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'complex', 'scab frog_eye_leaf_spot', 'complex', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'scab', 'healthy', 'scab', 'powdery_mildew complex', 'rust frog_eye_leaf_spot', 'frog_eye_leaf_spot complex', 'complex', 'frog_eye_leaf_spot', 'scab', 'scab', 'scab', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot', 'rust', 'scab', 'healthy', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'healthy', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'healthy', 'rust', 'frog_eye_leaf_spot', 'scab', 'scab', 'complex', 'scab', 'healthy', 'frog_eye_leaf_spot', 'rust', 'healthy', 'frog_eye_leaf_spot', 'healthy', 'rust', 'healthy', 'scab', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'rust', 'complex', 'healthy', 'healthy', 'frog_eye_leaf_spot', 'rust', 'scab frog_eye_leaf_spot', 'healthy', 'frog_eye_leaf_spot', 'rust', 'rust complex', 'healthy', 'scab', 'powdery_mildew', 'frog_eye_leaf_spot', 'scab', 'frog_eye_leaf_spot', 'scab', 'healthy', 'frog_eye_leaf_spot', 'complex', 'frog_eye_leaf_spot comple ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(actuallabels,testlabels)
print(f"Test accuracy score: {accuracy}")
# Out:
# Test accuracy score: 0.5671321160042965

# %%
actual_test = pd.read_csv('sample_submission.csv')

# %%
actual_test_data = datagen.flow_from_dataframe(
    actual_test,
    directory = './actual_test_images',
    x_col="image",
    y_col= None,
    color_mode="rgb",
    target_size = (256,256),
    classes=None,
    class_mode=None,
    batch_size=32,
    shuffle=False,
    seed=40,
)

actual_preds = new_model.predict(actual_test_data)
print(actual_preds)
actual_preds = actual_preds.tolist()

indices = []
for pred in actual_preds:
    temp = []
    for category in pred:
        if category>=0.3:
            temp.append(pred.index(category))
    if temp!=[]:
        pass
    else:
        temp.append(np.argmax(pred))
    # only add the predicted healthy labels, remove others
    if 2 in temp:
        temp = [2] # Resets the list 
    indices.append(temp)
    
print(indices)
# Out:
# Found 3 validated image filenames.
# [[2.0656985e-01 3.0279493e-01 3.0660033e-03 5.1325560e-04 9.3734264e-03
#   6.1404544e-01]
#  [6.2830710e-01 6.8453419e-01 2.8633773e-03 5.7405531e-03 1.5788969e-01
#   2.7454233e-01]
#  [1.8313774e-01 5.6889987e-01 9.5223784e-03 5.1814616e-03 1.1210641e-01
#   1.8911907e-01]]
# [[1, 5], [0, 1], [1]]

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)

actualtestlabels = []


for image in indices:
    temp = []
    for i in image:
        temp.append(str(labels[i]))
    actualtestlabels.append(' '.join(temp))

print(actualtestlabels)
# Out:
# {0: 'complex', 1: 'frog_eye_leaf_spot', 2: 'healthy', 3: 'powdery_mildew', 4: 'rust', 5: 'scab'}
# ['frog_eye_leaf_spot scab', 'complex frog_eye_leaf_spot', 'frog_eye_leaf_spot']

# %%
sub = pd.read_csv('./sample_submission.csv')
sub['labels'] = actualtestlabels
sub.to_csv('submission.csv', index=False)
sub
# Out:
#                   image                      labels
# 0  85f8cb619c66b863.jpg     frog_eye_leaf_spot scab
# 1  ad8770db05586b59.jpg  complex frog_eye_leaf_spot
# 2  c7b03e718489f3ca.jpg          frog_eye_leaf_spot
